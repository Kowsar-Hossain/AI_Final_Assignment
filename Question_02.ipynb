# %% [markdown]
# <a href="https://colab.research.google.com/github/Kowsar-Hossain/AI_Final_Assignment/blob/main/Question_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.layers import Input,Dense
from tensorflow.keras.models import Model
def main():
  inputs=Input((2,))
  h1=Dense(5,activation='relu',name="Hidden layer 1")(inputs)
  h2=Dense(6,activation='relu',name="Hidden layer 2")(h1)
  outputs=Dense(2,activation='softmax',name="Output layer")(h2)
  model=Model(inputs,outputs)
  model.summary(show_trainable=True)
if __name__=='__main__':
  main()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_4 (InputLayer)  │ (None, 2)             │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ Hidden layer 1 (Dense)      │ (None, 5)             │         15 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ Hidden layer 2 (Dense)      │ (None, 6)             │         36 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ Output layer (Dense)        │ (None, 2)             │         14 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 65 (260.00 B)
#  Trainable params: 65 (260.00 B)
#  Non-trainable params: 0 (0.00 B)
